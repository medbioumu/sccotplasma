# %%
from lazypredict.Supervised import LazyClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

data = pd.read_csv('pre5.txt',sep='\t')
col = data.columns.values.tolist()

X = np.array(data[col[1:278]])
y= data['Tendency']

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.2,random_state =38)
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models,predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 33.49it/s]
# [10:56:38] WARNING: D:\bld\xgboost-split_1637426510059\work\src\learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LinearSVC                          0.78               0.75     0.75      0.76
# XGBClassifier                      0.78               0.75     0.75      0.76
# RidgeClassifierCV                  0.78               0.75     0.75      0.76
# RidgeClassifier                    0.78               0.75     0.75      0.76
# Perceptron                         0.78               0.75     0.75      0.76
# PassiveAggressiveClassifier        0.78               0.75     0.75      0.76
# DecisionTreeClassifier             0.67               0.68     0.68      0.67
# ExtraTreeClassifier                0.67               0.65     0.65      0.66
# GaussianNB                         0.67               0.65     0.65      0.66
# NearestCentroid                    0.67               0.65     0.65      0.66
# LogisticRegression                 0.67               0.62     0.62      0.61
# KNeighborsClassifier               0.67               0.62     0.62      0.61
# SGDClassifier                      0.56               0.53     0.53      0.52
# AdaBoostClassifier                 0.56               0.53     0.53      0.52
# BernoulliNB                        0.56               0.53     0.53      0.52
# BaggingClassifier                  0.56               0.50     0.50      0.40
# LinearDiscriminantAnalysis         0.56               0.50     0.50      0.40
# NuSVC                              0.56               0.50     0.50      0.40
# LabelSpreading                     0.56               0.50     0.50      0.40
# LabelPropagation                   0.56               0.50     0.50      0.40
# RandomForestClassifier             0.56               0.50     0.50      0.40
# ExtraTreesClassifier               0.56               0.50     0.50      0.40
# CalibratedClassifierCV             0.56               0.50     0.50      0.40
# SVC                                0.56               0.50     0.50      0.40
# LGBMClassifier                     0.56               0.50     0.50      0.40
# QuadraticDiscriminantAnalysis      0.44               0.47     0.47      0.40
# DummyClassifier                    0.44               0.42     0.42      0.43
#
#                                Time Taken
# Model
# LinearSVC                            0.01
# XGBClassifier                        0.07
# RidgeClassifierCV                    0.02
# RidgeClassifier                      0.02
# Perceptron                           0.02
# PassiveAggressiveClassifier          0.02
# DecisionTreeClassifier               0.01
# ExtraTreeClassifier                  0.01
# GaussianNB                           0.01
# NearestCentroid                      0.02
# LogisticRegression                   0.03
# KNeighborsClassifier                 0.02
# SGDClassifier                        0.02
# AdaBoostClassifier                   0.12
# BernoulliNB                          0.01
# BaggingClassifier                    0.04
# LinearDiscriminantAnalysis           0.01
# NuSVC                                0.02
# LabelSpreading                       0.01
# LabelPropagation                     0.01
# RandomForestClassifier               0.14
# ExtraTreesClassifier                 0.10
# CalibratedClassifierCV               0.03
# SVC                                  0.01
# LGBMClassifier                       0.03
# QuadraticDiscriminantAnalysis        0.02
# DummyClassifier                      0.02
